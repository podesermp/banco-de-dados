# %%
import psycopg2

import ipywidgets as widgets
from ipywidgets import interact

# %%
#config
host = 'localhost'
dbname = 'fluxo_onibus-tb'
user = 'postgres'
password = 'postgres'
sslmode = 'require'
conn_string = 'host={0} user={1} dbname={2} password={3} sslmode={4}'.format(host, user, dbname, password, sslmode)

# %% [markdown]
# ### Interações com usuário

# %%
# campos de interação

anome = widgets.Text(
    value='',
    placeholder='Digite seu nome',
    description='Nome: ',
    disabled=False
)

nomeparada = widgets.Text(
    value='',
    placeholder='Digite o nome da parada',
    description='Nome: ',
    disabled=False
)

disciplina = widgets.Text(
    value='',
    placeholder='Digite o nome da disciplina',
    description='Nome da disciplina: ',
    disabled=False
)

curso = widgets.Text(
    value='',
    placeholder='Digite o curso',
    description='Nome do curso: ',
    disabled=False
)

horario = widgets.Text(
    value='',
    placeholder='HH:MM',
    description='Horário: ',
    disabled=False
)

afaculdade = widgets.Text(
    value='',
    placeholder='Digite o nome da sua faculdade',
    description='Faculdade: ',
    disabled=False
)

end_rua = widgets.Text(
    value='',
    placeholder='Digite a rua',
    description='Logadouro: ',
    disabled=False
)

end_num = widgets.IntText(
    min=0,
    value=0,
    description='Nº: ',
    disabled=False
)

end_bairro = widgets.Text(
    value='',
    placeholder='Digite o bairro',
    description='Bairro: ',
    disabled=False
)

end_cidade = widgets.Text(
    value='',
    placeholder='Digite a cidade',
    description='Cidade: ',
    disabled=False
)

id = widgets.IntText(
    min=0,
    value=0,
    description='ID: ',
    disabled=False
)

data = widgets.DatePicker(
    description='Selecione a data: ',
    disabled=False
)

# %% [markdown]
# ### Botões e funções - ALUNOS

# %%
# butões
button_c_aluno = widgets.Button(description="Inserir aluno")
button_r_aluno = widgets.Button(description="Ver alunos")
button_u_aluno = widgets.Button(description="Atualizar aluno")
button_d_aluno = widgets.Button(description="Remover aluno", value="insira a matrícula do aluno")


#funções
def create_aluno(b):
    try:
        output.clear_output()   
        display(id,anome, afaculdade, end_rua, end_num, end_bairro, end_cidade, button_c_aluno, button_d_aluno, button_r_aluno, button_u_aluno)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        query = f"INSERT INTO Aluno(nome,faculdade,end_rua, end_num, end_bairro, end_cidade) VALUES ('{anome.value}', '{afaculdade.value}', '{end_rua.value}', {int(end_num.value)}, '{end_bairro.value}', '{end_cidade.value}');"
        cursor.execute(query)
        conn.commit()
        print(f"{anome.value} adicionado!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

def delete_aluno(b):
    try:
        output.clear_output()   
        display(id,anome, afaculdade, end_rua, end_num, end_bairro, end_cidade, button_c_aluno, button_d_aluno, button_r_aluno, button_u_aluno)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        matriculas = []
        cursor.execute(f"SELECT id_aluno FROM aluno;")
        for t in cursor:
            matriculas.append(t[0])
        
        if id.value in matriculas:
            query = f"delete from aluno where id_aluno = {int(id.value)};"
            cursor.execute(query)
            conn.commit()
            print(f"{id.value} removido!")
        else:
            print(f"{id.value} não encontrado!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close() 
        
def update_aluno(b):
    try:
        output.clear_output()   
        display(id,anome, afaculdade, end_rua, end_num, end_bairro, end_cidade, button_c_aluno, button_d_aluno, button_r_aluno, button_u_aluno)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        matriculas = []
        cursor.execute(f"SELECT id_aluno FROM aluno;")
        for t in cursor:
            matriculas.append(t[0])
        if id.value in matriculas:
            conn = psycopg2.connect(conn_string)
            cursor = conn.cursor()
            query = f"UPDATE aluno SET nome = '{anome.value}', faculdade = '{afaculdade.value}', end_rua='{end_rua.value}', end_num={end_num.value}, end_bairro='{end_bairro.value}', end_cidade='{end_cidade.value}' WHERE id_aluno={id.value}"
            cursor.execute(query)
            conn.commit()
            print(f"{anome.value} atualizado!")
        else:
            print(f"Matrícula {id.value} não encontrada!")
        
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

def read_aluno(b):
    try:
        output.clear_output()   
        display(id,anome, afaculdade, end_rua, end_num, end_bairro, end_cidade, button_c_aluno, button_d_aluno, button_r_aluno, button_u_aluno)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        cursor.execute(f"SELECT id_aluno, nome FROM aluno;")
        for t in cursor:
            print(f"{t[0]} - {t[1]}")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()
        
# associações de botões com funções
button_c_aluno.on_click(create_aluno)
button_r_aluno.on_click(read_aluno)
button_u_aluno.on_click(update_aluno)
button_d_aluno.on_click(delete_aluno)

# %%
output = widgets.Output()
with output:
    output.clear_output()   
    display(id,anome, afaculdade, end_rua, end_num, end_bairro, end_cidade, button_c_aluno, button_d_aluno, button_r_aluno, button_u_aluno)
output
# Out:
# Output()

# %% [markdown]
# ### Botões e funções - AULA

# %%
# butões
button_c_aula = widgets.Button(description="Cadastrar aula")
button_r_aula = widgets.Button(description="Ver aula")
button_u_aula = widgets.Button(description="Atualizar aula")
button_d_aula = widgets.Button(description="Remover aula", value="insira id da aula")

def create_aula(b):
    try:
        output.clear_output()   
        display(id, disciplina, afaculdade, curso, horario, button_c_aula, button_d_aula,button_r_aula, button_u_aula)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        query = f"INSERT INTO aula(nome, faculdade, curso, horario) VALUES ('{disciplina.value}', '{afaculdade.value}', '{curso.value}', '{horario.value}');"
        cursor.execute(query)
        conn.commit()
        print(f"{disciplina.value} cadastrada!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()
        
def delete_aula(b):
    try:
        output.clear_output()   
        display(id, disciplina, afaculdade, curso, horario, button_c_aula, button_d_aula,button_r_aula, button_u_aula)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        ids = []
        cursor.execute(f"SELECT id_aula FROM aula;")
        for t in cursor:
            ids.append(t[0])
        
        if id.value in ids:
            query = f"delete from aula where id_aula = {int(id.value)};"
            cursor.execute(query)
            conn.commit()
            print(f"{id.value} removido!")
        else:
            print(f"{id.value} não encontrado!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

def read_aula(b):
    try:
        output.clear_output()
        display(id, disciplina, afaculdade, curso, horario, button_c_aula, button_d_aula,button_r_aula, button_u_aula)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        cursor.execute(f"SELECT nome, id_aula FROM aula;")
        for t in cursor:
            print(f"{t[1]} - {t[0]}")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()
        
        
def update_aula(b):
    try:
        output.clear_output()   
        display(id, disciplina, afaculdade, curso, horario, button_c_aula, button_d_aula,button_r_aula, button_u_aula)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        ids = []
        cursor.execute(f"SELECT id_aula FROM aula;")
        for t in cursor:
            ids.append(t[0])
        
        if id.value in ids:
            conn = psycopg2.connect(conn_string)
            cursor = conn.cursor()
            query = f"UPDATE aula SET nome = '{disciplina.value}', faculdade = '{afaculdade.value}', curso='{curso.value}', horario='{horario.value}' WHERE id_aula={id.value}"
            cursor.execute(query)
            conn.commit()
            print(f"{disciplina.value} atualizado!")
        else:
            print(f"ID {id.value} não encontrado!")
        
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

button_c_aula.on_click(create_aula)
button_d_aula.on_click(delete_aula)
button_r_aula.on_click(read_aula)
button_u_aula.on_click(update_aula)

# %%
output = widgets.Output()
with output:
    output.clear_output()   
    display(id, disciplina, afaculdade, curso, horario, button_c_aula, button_d_aula,button_r_aula, button_u_aula)
output
# Out:
# Output()

# %% [markdown]
# ### Botões e funções - HORÁRIO

# %%
button_c_horario = widgets.Button(description="Cadastrar horario")
button_r_horario = widgets.Button(description="Ver horario")
button_u_horario = widgets.Button(description="Atualizar horario")
button_d_horario = widgets.Button(description="Remover horario", value="insira id da horario")


def create_horario(b):
    try:
        output.clear_output()   
        display(id, horario, data, button_c_horario, button_d_horario, button_r_horario, button_u_horario)
        
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        query = f"INSERT INTO horario(horario, data) VALUES('{horario.value}', '{data.value}');"
        cursor.execute(query)
        conn.commit()
        print(f"Horário cadastrado!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

def read_horario(b):
    try:
        output.clear_output()
        display(id, horario, data, button_c_horario, button_d_horario, button_r_horario, button_u_horario)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        cursor.execute(f"SELECT horario, id_horario FROM horario;")
        for t in cursor:
            print(f"{t[1]} - {t[0]}")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()
        
def update_horario(b):
    try:
        output.clear_output()   
        display(id, horario, data, button_c_horario, button_d_horario, button_r_horario, button_u_horario)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        ids = []
        cursor.execute(f"SELECT id_horario FROM horario;")
        for t in cursor:
            ids.append(t[0])
        
        if id.value in ids:
            conn = psycopg2.connect(conn_string)
            cursor = conn.cursor()
            query = f"UPDATE horario SET horario = '{horario.value}', data = '{data.value}' WHERE id_horario={id.value}"
            cursor.execute(query)
            conn.commit()
            print(f"Horário atualizado!")
        else:
            print(f"ID {id.value} não encontrado!")
        
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()
    
def delete_horario(b):
    try:
        output.clear_output()   
        display(id, horario, data, button_c_horario, button_d_horario, button_r_horario, button_u_horario)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        ids = []
        cursor.execute(f"SELECT id_horario FROM horario;")
        for t in cursor:
            ids.append(t[0])
        
        if id.value in ids:
            query = f"delete from horario where id_horario = {int(id.value)};"
            cursor.execute(query)
            conn.commit()
            print(f"{id.value} removido!")
        else:
            print(f"{id.value} não encontrado!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

button_c_horario.on_click(create_horario)
button_r_horario.on_click(read_horario)
button_u_horario.on_click(update_horario)
button_d_horario.on_click(delete_horario)

# %%
output = widgets.Output()
with output:
    output.clear_output()   
    display(id, horario, data, button_c_horario, button_d_horario, button_r_horario, button_u_horario)
output
# Out:
# Output()

# %%
button_c_parada = widgets.Button(description="Cadastrar parada")
button_r_parada = widgets.Button(description="Ver paradas")
button_u_parada = widgets.Button(description="Atualizar parada")
button_d_parada = widgets.Button(description="Remover parada", value="insira id da parada")


def create_parada(b):
    try:
        output.clear_output()   
        display(id, nomeparada, end_rua, end_num, end_bairro, end_cidade, button_c_parada, button_d_parada, button_r_parada, button_u_parada)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        query = f"INSERT INTO ponto_parada(nome, end_rua, end_num, end_bairro, end_cidade) VALUES ('{nomeparada.value}', '{end_rua.value}', {end_num.value}, '{end_bairro.value}', '{end_cidade.value}');"
        cursor.execute(query)
        conn.commit()
        print(f"{nomeparada.value} adicionado!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

def delete_parada(b):
    try:
        output.clear_output()   
        display(id, nomeparada, end_rua, end_num, end_bairro, end_cidade, button_c_parada, button_d_parada, button_r_parada, button_u_parada)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        ids = []
        cursor.execute(f"SELECT id_ponto_parada FROM ponto_parada;")
        for t in cursor:
            ids.append(t[0])
        
        if id.value in ids:
            query = f"delete from ponto_parada where id_ponto_parada = {id.value};"
            cursor.execute(query)
            conn.commit()
            print(f"{id.value} removido!")
        else:
            print(f"{id.value} não encontrado!")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close() 
        
def update_parada(b):
    try:
        output.clear_output()   
        display(id, nomeparada, end_rua, end_num, end_bairro, end_cidade, button_c_parada, button_d_parada, button_r_parada, button_u_parada)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        ids = []
        cursor.execute(f"SELECT id_ponto_parada FROM ponto_parada;")
        for t in cursor:
            ids.append(t[0])
            
        if id.value in ids:
            conn = psycopg2.connect(conn_string)
            cursor = conn.cursor()
            query = f"UPDATE ponto_parada SET nome = '{nomeparada.value}', end_rua='{end_rua.value}', end_num={end_num.value}, end_bairro='{end_bairro.value}', end_cidade='{end_cidade.value}'WHERE id_ponto_parada={id.value}"
            cursor.execute(query)
            conn.commit()
            print(f"{nomeparada.value} atualizado!")
        else:
            print(f"{id.value} não encontrado!")
        
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

def read_parada(b):
    try:
        output.clear_output()   
        display(id, nomeparada, end_rua, end_num, end_bairro, end_cidade, button_c_parada, button_d_parada, button_r_parada, button_u_parada)
        conn = psycopg2.connect(conn_string)
        cursor = conn.cursor()
        
        cursor.execute(f"SELECT id_ponto_parada, nome FROM ponto_parada;")
        for t in cursor:
            print(f"{t[0]} - {t[1]}")
    except Exception as erro:
        print(f"ERRO: {erro}")
    finally:
        conn.close()
        cursor.close()

button_c_parada.on_click(create_parada)
button_d_parada.on_click(delete_parada)
button_r_parada.on_click(read_parada)
button_u_parada.on_click(update_parada)

# %%
output = widgets.Output()
with output:
    output.clear_output()  
    display(id, nomeparada, end_rua, end_num, end_bairro, end_cidade, button_c_parada, button_d_parada, button_r_parada, button_u_parada)
output
# Out:
# Output()
